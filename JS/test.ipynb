# %%
from Bio.Affy import CelFile
import numpy as np
import matplotlib.pyplot as plt
with open("C:\\Users\\Nilesh Bhanot\\Desktop\\GSM706039.CEL") as handle:
    c = CelFile.read(handle)
    print(c.intensities)
    arr = np.array(c.intensities)
    arr = arr.reshape((712, 712, -1))
    print(arr.shape)
    plt.imshow(arr)
# Out:
# [[ 106.5 3996.8  106.3 ... 5021.5  104.  5421.3]
#  [3940.    98.  3801.5 ...  104.5 4703.8  105. ]
#  [ 104.  3829.5  106.8 ... 4659.3   99.3 5229.5]
#  ...
#  [4656.8  109.  4355.8 ...  109.  4620.    95.5]
#  [ 101.3 4476.8  112.8 ... 4663.    98.3 4853.8]
#  [5301.8  101.5 4930.5 ...  101.  5012.3   92.8]]
# (712, 712, 1)
